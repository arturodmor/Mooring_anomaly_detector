# %% [markdown]
# # 1.3. How to analyse data performance with representation tools

# %%
from anchoring_detection.preprocess import Preprocess
from anchoring_detection.analysis import Analysis
import pickle as pkl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import os

# %% [markdown]
# ## Time domain Analysis

# %% [markdown]
# We repeat the dataframe construction like notebook *1.1.Build datasets* before to represent data

# %%
drag_analysis = Analysis()

# %%
drag_analysis.extract_res_files()
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/preprocess.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col] - df[col].mean()

# %%
drag_analysis.dataframe_for_analysis()
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)

# %%
drag_analysis.df_sway
# Out:
#          Time  oc4__Hs1__Tp2__dir1__1.txt  oc4__Hs1__Tp2__dir1__2.txt  \
# 0       180.0                   -1.264705                    -5.31605
# 1       180.1                   -1.264875                    -5.31506
# 2       180.2                   -1.265005                    -5.31402
# 3       180.3                   -1.265085                    -5.31293
# 4       180.4                   -1.265105                    -5.31179
# ...       ...                         ...                         ...
# 10196  1199.6                    0.095555                     0.81443
# 10197  1199.7                    0.099955                     0.81883
# 10198  1199.8                    0.104285                     0.82323
# 10199  1199.9                    0.108505                     0.82743
# 10200  1200.0                    0.112605                     0.83153
#
#        oc4__Hs1__Tp2__dir1__3.txt  oc4__Hs1__Tp2__dir1__4.txt  \
# 0                       -3.764274                   -2.371238
# 1                       -3.763454                   -2.370778
# 2                       -3.762604                   -2.370268
# 3                       -3.761704                   -2.369718
# 4                       -3.760754                   -2.369108
# ...                           ...                         ...
# 10196                    0.403096                    0.187902
# 10197                    0.407496                    0.192312
# 10198                    0.411836                    0.196632
# 10199                    0.416066                    0.200862
# 10200                    0.420166                    0.204962
#
#        oc4__Hs1__Tp2__dir2__1.txt  oc4__Hs1__Tp2__dir2__2.txt  \
# 0                        -1.19927                   -5.250818
# 1                        -1.19308                   -5.243458
# 2                        -1.18728                   -5.236498
# 3                        -1.18191                   -5.229958
# 4                        -1.17698                   -5.223868
# ...                           ...                         ...
# 10196                    -0.05398                    0.665052
# 10197                    -0.05181                    0.667152
# 10198                    -0.04938                    0.669652
# 10199                    -0.04666                    0.672352
# 10200                    -0.04363                    0.675452
#
#        oc4__Hs1__Tp2__dir3__1.txt  oc4__Hs1__Tp2__dir3__2.txt  \
# 0                       -1.229452                   -5.281068
# 1                       -1.222732                   -5.273178
# 2                       -1.215962                   -5.265248
# 3                       -1.209182                   -5.257288
# 4                       -1.202402                   -5.249348
# ...                           ...                         ...
# 10196                   -0.079232                    0.639732
# 10197                   -0.075322                    0.643632
# 10198                   -0.071282                    0.647732
# 10199                   -0.067132                    0.651932
# 10200                   -0.062862                    0.656132
#
#        oc4__Hs1__Tp2__dir4__1.txt  ...  oc4__Hs4__Tp5__dir1__3.txt  \
# 0                        -1.22683  ...                   -3.735165
# 1                        -1.21847  ...                   -3.735335
# 2                        -1.21028  ...                   -3.735165
# 3                        -1.20227  ...                   -3.734665
# 4                        -1.19449  ...                   -3.733835
# ...                           ...  ...                         ...
# 10196                    -0.07068  ...                    0.372095
# 10197                    -0.06845  ...                    0.369975
# 10198                    -0.06600  ...                    0.368185
# 10199                    -0.06334  ...                    0.366735
# 10200                    -0.06050  ...                    0.365625
#
#        oc4__Hs4__Tp5__dir1__4.txt  oc4__Hs4__Tp5__dir2__1.txt  \
# 0                       -2.347157                   -0.487378
# 1                       -2.347697                   -0.387288
# 2                       -2.347897                   -0.286158
# 3                       -2.347757                   -0.184128
# 4                       -2.347297                   -0.081318
# ...                           ...                         ...
# 10196                    0.163903                    5.210922
# 10197                    0.161783                    5.264522
# 10198                    0.159993                    5.314022
# 10199                    0.158533                    5.359522
# 10200                    0.157423                    5.401022
#
#        oc4__Hs4__Tp5__dir2__2.txt  oc4__Hs4__Tp5__dir3__1.txt  \
# 0                       -4.517907                   -0.292194
# 1                       -4.416787                   -0.177594
# 2                       -4.314627                   -0.061914
# 3                       -4.211557                    0.054726
# 4                       -4.107707                    0.172176
# ...                           ...                         ...
# 10196                    5.908613                    6.056456
# 10197                    5.962113                    6.121656
# 10198                    6.011713                    6.181956
# 10199                    6.057213                    6.237156
# 10200                    6.098613                    6.287456
#
#        oc4__Hs4__Tp5__dir3__2.txt  oc4__Hs4__Tp5__dir4__1.txt  \
# 0                       -4.336293                   -0.329424
# 1                       -4.220703                   -0.229844
# 2                       -4.104023                   -0.129434
# 3                       -3.986383                   -0.028294
# 4                       -3.867923                    0.073476
# ...                           ...                         ...
# 10196                    6.733517                    5.277406
# 10197                    6.798817                    5.338106
# 10198                    6.859117                    5.394406
# 10199                    6.914417                    5.446306
# 10200                    6.964717                    5.493506
#
#        oc4__Hs4__Tp5__dir4__2.txt  oc4__Hs4__Tp5__dir5__1.txt  \
# 0                       -4.388174                    -1.11546
# 1                       -4.287594                    -1.10957
# 2                       -4.186174                    -1.10405
# 3                       -4.084014                    -1.09887
# 4                       -3.981224                    -1.09403
# ...                           ...                         ...
# 10196                    5.933866                     0.10249
# 10197                    5.994766                     0.10446
# 10198                    6.051066                     0.10610
# 10199                    6.102966                     0.10740
# 10200                    6.150266                     0.10836
#
#        oc4__Hs4__Tp5__dir5__2.txt
# 0                       -5.160092
# 1                       -5.153092
# 2                       -5.146452
# 3                       -5.140152
# 4                       -5.134192
# ...                           ...
# 10196                    0.785228
# 10197                    0.787228
# 10198                    0.788828
# 10199                    0.790128
# 10200                    0.791128
#
# [10201 rows x 121 columns]

# %% [markdown]
# So far, only the optimal anchoring state (1) will be compared with the 30 m anchor displacement case (2). This is because cases (3) and (4) are not yet complete, and the data set in general will undergo transformations in the future.

# %%
drag_analysis.plot_spectral_comparison(mov='Surge')
