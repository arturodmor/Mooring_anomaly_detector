# %% [markdown]
# # 1.1. How to manage *anchoring_detection* package

# %%
from anchoring_detection.preprocess import Preprocess
from anchoring_detection.analysis import Analysis
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import os

# %% [markdown]
# ## Preparing the data

# %%
drag_preprocess = Preprocess()

# %%
"""drag_preprocess.work_definitions(aumentation='no')""" # The class add new simulations default. If you want to deprecate it, execute this line
# Out:
# "drag_preprocess.work_definitions(aumentation='no')"

# %%
drag_preprocess.extract_res_files() # Return a dictionary with all Dataframes for Surge and Sway
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/preprocess.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col] - df[col].mean()

# %%
drag_preprocess.dataframes_surge['oc4__Hs1__Tp2__dir3__1']
# Out:
#        time[s]     Surge
# 0        180.0 -1.479151
# 1        180.1 -1.476411
# 2        180.2 -1.473671
# 3        180.3 -1.470971
# 4        180.4 -1.468291
# ...        ...       ...
# 10196   1199.6  0.067959
# 10197   1199.7  0.064109
# 10198   1199.8  0.060319
# 10199   1199.9  0.056589
# 10200   1200.0  0.052949
#
# [10201 rows x 2 columns]

# %% [markdown]
# ## Build the different dataset options

# %% [markdown]
# ### Time domain dataset

# %%
drag_analysis = Analysis()

# %%
drag_analysis.dataframe_for_analysis()
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)

# %%
drag_analysis.df_surge
# Out:
#          Time  oc4__Hs1__Tp2__dir1__1.txt  oc4__Hs1__Tp2__dir1__2.txt  \
# 0       180.0                   -1.493449                   -7.806978
# 1       180.1                   -1.487229                   -7.794478
# 2       180.2                   -1.481179                   -7.782078
# 3       180.3                   -1.475329                   -7.769978
# 4       180.4                   -1.469719                   -7.758078
# ...       ...                         ...                         ...
# 10196  1199.6                   -0.061139                    0.587722
# 10197  1199.7                   -0.056619                    0.592322
# 10198  1199.8                   -0.051839                    0.597022
# 10199  1199.9                   -0.046819                    0.602122
# 10200  1200.0                   -0.041589                    0.607322
#
#        oc4__Hs1__Tp2__dir1__3.txt  oc4__Hs1__Tp2__dir1__4.txt  \
# 0                       -3.719421                   -1.464663
# ...

# %% [markdown]
# ### Frequency domain dataset

# %%
drag_preprocess.fourier() #FFT

# %%
drag_analysis.dataframes_surge['oc4__Hs1__Tp2__dir1__4'] # User can check the dataframes out with both preprocess and analysis class
# Out:
#       Frequencies    Amplitudes
# 0        0.000000  1.832777e-17
# 1        0.000980  7.787562e-02
# 2        0.001961  8.883191e-02
# 3        0.002941  7.709272e-02
# 4        0.003921  6.140394e-02
# ...           ...           ...
# 5095     4.994608  6.937306e-05
# 5096     4.995589  6.939295e-05
# 5097     4.996569  6.937915e-05
# 5098     4.997549  6.936382e-05
# 5099     4.998530  6.935722e-05
#
# [5100 rows x 2 columns]

# %%
drag_analysis.dataframe_for_analysis(domain='Frequency')
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)

# %%
drag_analysis.df_surge
# Out:
#       Frequency  oc4__Hs1__Tp2__dir1__1.txt  oc4__Hs1__Tp2__dir1__2.txt  \
# 0      0.000000                1.354339e-16                6.481326e-16
# 1      0.000980                9.272685e-02                6.962502e-01
# 2      0.001961                1.090906e-01                5.823722e-01
# 3      0.002941                1.040265e-01                4.422400e-01
# 4      0.003921                8.015641e-02                3.390597e-01
# ...         ...                         ...                         ...
# 5095   4.994608                7.146223e-05                4.130124e-04
# 5096   4.995589                7.145788e-05                4.125877e-04
# 5097   4.996569                7.144889e-05                4.127803e-04
# 5098   4.997549                7.147529e-05                4.127974e-04
# 5099   4.998530                7.145586e-05                4.131894e-04
#
#       oc4__Hs1__Tp2__dir1__3.txt  oc4__Hs1__Tp2__dir1__4.txt  \
# ...

# %% [markdown]
# ### Spectral moment dataset

# %%
drag_preprocess.moment_dataset() # Currently, the training models are using spectral moments, and that is the reason which the method save the data in .pkl file
