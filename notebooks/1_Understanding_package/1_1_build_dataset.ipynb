# %% [markdown]
# # How to manage *anchoring_detection* package

# %%
from anchoring_detection.preprocess import Preprocess
from anchoring_detection.analysis import Analysis
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import os

# %% [markdown]
# ## Preparing the data

# %%
anchoring = Preprocess()

# %%
"""anchoring.work_definitions(aumentation='no')""" # The class add new simulations default. If you want to deprecate it, execute this line
# Out:
# "anchoring.work_definitions(aumentation='no')"

# %%
anchoring.extract_res_files() # Return a dictionary with all Dataframes for Surge and Sway
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/preprocess.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col] - df[col].mean()

# %%
anchoring.dataframes_surge['oc4__Hs1__Tp2__dir3__1']
# Out:
#        time[s]     Surge
# 0        180.0 -1.479151
# 1        180.1 -1.476411
# 2        180.2 -1.473671
# 3        180.3 -1.470971
# 4        180.4 -1.468291
# ...        ...       ...
# 10196   1199.6  0.067959
# 10197   1199.7  0.064109
# 10198   1199.8  0.060319
# 10199   1199.9  0.056589
# 10200   1200.0  0.052949
#
# [10201 rows x 2 columns]

# %% [markdown]
# ## Build the different dataset options

# %% [markdown]
# ### Time domain dataset

# %%
study = Analysis()

# %%
study.dataframe_for_analysis()
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)

# %%
study.df_surge
# Out:
#        time[s]  oc4__Hs1__Tp2__dir3__1.txt  oc4__Hs3__Tp5__dir1__3.txt  \
# 0        180.0                   -1.493449                   -7.806978
# 1        180.1                   -1.487229                   -7.794478
# 2        180.2                   -1.481179                   -7.782078
# 3        180.3                   -1.475329                   -7.769978
# 4        180.4                   -1.469719                   -7.758078
# ...        ...                         ...                         ...
# 10196   1199.6                   -0.061139                    0.587722
# 10197   1199.7                   -0.056619                    0.592322
# 10198   1199.8                   -0.051839                    0.597022
# 10199   1199.9                   -0.046819                    0.602122
# 10200   1200.0                   -0.041589                    0.607322
#
#        oc4__Hs1__Tp4__dir2__2.txt  oc4__Hs1__Tp5__dir1__1.txt  \
# ...

# %% [markdown]
# ### Frequency domain dataset

# %%
anchoring.fourier() #FFT

# %%
study.dataframe_for_analysis(domain='Frequency')
# Out:
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)
# /home/arturo/Documentos/Mooring_anomaly_detector/anchoring_detection/analysis.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(0,domain,df_domain)

# %%
study.df_surge
# Out:
#       Frequency  Frequencies    Amplitudes  Frequencies    Amplitudes  \
# 0      0.000000     0.000000  1.354339e-16     0.000000  6.481326e-16
# 1      0.000980     0.000980  9.272685e-02     0.000980  6.962502e-01
# 2      0.001961     0.001961  1.090906e-01     0.001961  5.823722e-01
# 3      0.002941     0.002941  1.040265e-01     0.002941  4.422400e-01
# 4      0.003921     0.003921  8.015641e-02     0.003921  3.390597e-01
# ...         ...          ...           ...          ...           ...
# 5095   4.994608     4.994608  7.146223e-05     4.994608  4.130124e-04
# 5096   4.995589     4.995589  7.145788e-05     4.995589  4.125877e-04
# 5097   4.996569     4.996569  7.144889e-05     4.996569  4.127803e-04
# 5098   4.997549     4.997549  7.147529e-05     4.997549  4.127974e-04
# 5099   4.998530     4.998530  7.145586e-05     4.998530  4.131894e-04
#
#       Frequencies    Amplitudes  Frequencies    Amplitudes  Frequencies  ...  \
# ...

# %% [markdown]
# ### Spectral moment dataset

# %%
anchoring.moment_dataset() # Currently, the training models are using spectral moments, and that is the reason which the method save the data in .pkl file
# Out:
#                           Hs     Tp  Direction  m0_Surge   m0_Sway  Dragging
# oc4__Hs1__Tp2__dir1__1  1.21   8.15          0  0.002438  0.001749         0
# oc4__Hs1__Tp2__dir1__2  1.21   8.15          0  0.011784  0.008595         1
# oc4__Hs1__Tp2__dir1__3  1.21   8.15          0  0.005411  0.005698         1
# oc4__Hs1__Tp2__dir1__4  1.21   8.15          0  0.002285  0.003390         1
# oc4__Hs1__Tp2__dir2__1  1.21   8.15         60  0.002250  0.001852         0
# ...                      ...    ...        ...       ...       ...       ...
# oc4__Hs4__Tp5__dir3__2  8.10  18.69         90  0.012230  0.018121         1
# oc4__Hs4__Tp5__dir4__1  8.10  18.69        120  0.005428  0.010878         0
# oc4__Hs4__Tp5__dir4__2  8.10  18.69        120  0.012206  0.016706         1
# oc4__Hs4__Tp5__dir5__1  8.10  18.69        180  0.011085  0.002734         0
# oc4__Hs4__Tp5__dir5__2  8.10  18.69        180  0.013946  0.009060         1
#
# [120 rows x 6 columns]
